# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import warnings
warnings.filterwarnings('ignore')
import optuna
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import category_encoders as ce
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder,StandardScaler,OrdinalEncoder,TargetEncoder,PowerTransformer
from sklearn.compose import ColumnTransformer,TransformedTargetRegressor
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split,GridSearchCV,cross_val_score,KFold,RandomizedSearchCV
from lightgbm import LGBMRegressor
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.neural_network import MLPRegressor
from xgboost import XGBRegressor
import xgboost as xgb
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
import optuna
from plotly.io import show
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
df = pd.read_csv('final_data.csv')
df = df.drop(['Title','Price_per_sqft','Is_in_Dhaka'],axis=1)
df.head()
# Out:
#    Bedrooms  Bathrooms  Floor_area   City location_area  Price_in_Cr  \
# 0       3.0        4.0      1960.0  dhaka       gulshan         3.90
# 1       3.0        3.0      1705.0  dhaka     kalabagan         1.69
# 2       3.0        3.0      1370.0  dhaka     dhanmondi         1.25
# 3       3.0        3.0      2125.0  dhaka   bashundhara         2.00
# 4       3.0        3.0      2687.0  dhaka        banani         4.75
#
#   floor_level
# 0         low
# 1         low
# 2      medium
# 3      medium
# 4      medium

# %%
x = df.drop('Price_in_Cr',axis=1)
y = df['Price_in_Cr']

# %% [markdown]
# # Optuna

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)


floor_area_pipe = Pipeline([
    ('log_transform',PowerTransformer(method='yeo-johnson')),
    ('scalar',StandardScaler())
])

transformer = ColumnTransformer([
    ("floor_area",floor_area_pipe,['Floor_area']),
    ("log_transform",PowerTransformer(method='yeo-johnson'),['Floor_area']),
    ('Onehot',OneHotEncoder(handle_unknown='ignore',sparse_output=False),['City','Bedrooms','Bathrooms','location_area']),
    ('Ordinal',OrdinalEncoder(handle_unknown='use_encoded_value',unknown_value=-1),['floor_level']),
],remainder='passthrough')


def objective(trial,preprocessor):
    regressor_name = trial.suggest_categorical('regressor',['GradientBoostingRegressor'])

    if regressor_name == 'GradientBoostingRegressor':
        n_estimators = trial.suggest_int('model__n_estimators',50,300)
        learning_rate = trial.suggest_float('model__learning_rate',0.05,0.3)
        max_features = trial.suggest_categorical('model__max_features',['sqrt', 'log2'])
        subsample = trial.suggest_float('model__subsample',0.7,1.0)
        max_depth = trial.suggest_int('model__max_depth',3,6)
        min_samples_leaf = trial.suggest_int('model__min_samples_leaf',1,5)
        min_samples_split = trial.suggest_int('model__min_samples_split',2,5)


    model_pipe = Pipeline([
        ('preprocessor',transformer),
        ('model',GradientBoostingRegressor(n_estimators=n_estimators,learning_rate=learning_rate,max_features=max_features,
                                           max_depth=max_depth,min_samples_leaf=min_samples_leaf,
                                           min_samples_split=min_samples_split,subsample=subsample,random_state=0))
                                           ])

    final_pipe = TransformedTargetRegressor(regressor=model_pipe,func=np.log1p,inverse_func=np.expm1)

    trial.set_user_attr('model',final_pipe)

    cv_score = cross_val_score(final_pipe,x_train,y_train,cv=KFold(n_splits=10,shuffle=True,random_state=0),scoring='neg_mean_squared_error')
    return cv_score.mean()


study = optuna.create_study(direction='maximize',sampler=optuna.samplers.TPESampler(seed=0),pruner=optuna.pruners.HyperbandPruner())
study.optimize(lambda trial : objective(trial,preprocessor=transformer),n_trials=100,n_jobs=-1)
print(f'Best neg score: {study.best_value}')
print(f'Best Params: {study.best_params}')

final_model = study.best_trial.user_attrs['model']
final_model.fit(x_train,y_train)
y_pred = final_model.predict(x_test)

print(f'MSE: {mean_squared_error(y_test,y_pred)}')
print(f'MAE: {mean_absolute_error(y_test,y_pred)}')
print(f'R2: {r2_score(y_test,y_pred)}')
# Out:
# [I 2025-09-26 17:35:59,016] A new study created in memory with name: no-name-17841f17-36de-49e5-8e2c-83fbdffb7243
# [I 2025-09-26 17:36:06,824] Trial 2 finished with value: -0.10443517900930888 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 62, 'model__learning_rate': 0.11538484407003717, 'model__max_features': 'sqrt', 'model__subsample': 0.8296169748742077, 'model__max_depth': 4, 'model__min_samples_leaf': 5, 'model__min_samples_split': 3}. Best is trial 2 with value: -0.10443517900930888.
# [I 2025-09-26 17:36:08,442] Trial 11 finished with value: -0.07920499876749743 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 79, 'model__learning_rate': 0.13881757032405923, 'model__max_features': 'sqrt', 'model__subsample': 0.9991018243666185, 'model__max_depth': 6, 'model__min_samples_leaf': 2, 'model__min_samples_split': 2}. Best is trial 11 with value: -0.07920499876749743.
# [I 2025-09-26 17:36:08,646] Trial 1 finished with value: -0.09846724298015595 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 83, 'model__learning_rate': 0.08192159444974957, 'model__max_features': 'sqrt', 'model__subsample': 0.9947276094045708, 'model__max_depth': 3, 'model__min_samples_leaf': 1, 'model__min_samples_split': 5}. Best is trial 11 with value: -0.07920499876749743.
# [I 2025-09-26 17:36:10,037] Trial 6 finished with value: -0.08844563514173123 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 104, 'model__learning_rate': 0.2632855127670587, 'model__max_features': 'sqrt', 'model__subsample': 0.7233318145419232, 'model__max_depth': 3, 'model__min_samples_leaf': 2, 'model__min_samples_split': 3}. Best is trial 11 with value: -0.07920499876749743.
# [I 2025-09-26 17:36:12,716] Trial 7 finished with value: -0.06200511376757413 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 134, 'model__learning_rate': 0.2700045559489739, 'model__max_features': 'sqrt', 'model__subsample': 0.9961388057454358, 'model__max_depth': 4, 'model__min_samples_leaf': 1, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:36:13,280] Trial 5 finished with value: -0.08442128824730595 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 134, 'model__learning_rate': 0.12310114058310927, 'model__max_features': 'sqrt', 'model__subsample': 0.8550993882427081, 'model__max_depth': 6, 'model__min_samples_leaf': 4, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:36:13,331] Trial 0 finished with value: -0.11418660034257448 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 136, 'model__learning_rate': 0.07705340304854501, 'model__max_features': 'log2', 'model__subsample': 0.9683945233446107, 'model__max_depth': 3, 'model__min_samples_leaf': 2, 'model__min_samples_split': 4}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:36:16,837] Trial 10 finished with value: -0.0634680082719122 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 182, 'model__learning_rate': 0.21967917835802703, 'model__max_features': 'log2', 'model__subsample': 0.9288513591953441, 'model__max_depth': 3, 'model__min_samples_leaf': 1, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:36:18,200] Trial 9 finished with value: -0.09121618710296872 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 206, 'model__learning_rate': 0.23570105695457227, 'model__max_features': 'log2', 'model__subsample': 0.8315642820051818, 'model__max_depth': 4, 'model__min_samples_leaf': 4, 'model__min_samples_split': 3}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:36:19,215] Trial 8 finished with value: -0.08246061600522873 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 231, 'model__learning_rate': 0.06982221231126774, 'model__max_features': 'sqrt', 'model__subsample': 0.7018711349795229, 'model__max_depth': 5, 'model__min_samples_leaf': 5, 'model__min_samples_split': 4}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:36:19,670] Trial 4 finished with value: -0.06485588844163548 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 209, 'model__learning_rate': 0.21926804494359364, 'model__max_features': 'log2', 'model__subsample': 0.9149614928223421, 'model__max_depth': 6, 'model__min_samples_leaf': 1, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:36:19,775] Trial 12 finished with value: -0.10484768643625655 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 141, 'model__learning_rate': 0.05587418931101047, 'model__max_features': 'log2', 'model__subsample': 0.7473035944859806, 'model__max_depth': 5, 'model__min_samples_leaf': 4, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:36:22,729] Trial 17 finished with value: -0.07688104938469567 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 91, 'model__learning_rate': 0.29832969893178685, 'model__max_features': 'log2', 'model__subsample': 0.9214565828263972, 'model__max_depth': 3, 'model__min_samples_leaf': 1, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:36:23,728] Trial 16 finished with value: -0.07254798533214205 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 113, 'model__learning_rate': 0.2462487909799016, 'model__max_features': 'log2', 'model__subsample': 0.8701331725606021, 'model__max_depth': 6, 'model__min_samples_leaf': 1, 'model__min_samples_split': 4}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:36:24,053] Trial 3 finished with value: -0.09000245957217276 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 280, 'model__learning_rate': 0.19808907393716413, 'model__max_features': 'sqrt', 'model__subsample': 0.8299374753482895, 'model__max_depth': 3, 'model__min_samples_leaf': 5, 'model__min_samples_split': 3}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:36:26,039] Trial 14 finished with value: -0.06564558043964626 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 202, 'model__learning_rate': 0.12474785821419494, 'model__max_features': 'log2', 'model__subsample': 0.7896106263435916, 'model__max_depth': 5, 'model__min_samples_leaf': 1, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:36:27,409] Trial 13 finished with value: -0.07080588691124758 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 210, 'model__learning_rate': 0.06502228821096705, 'model__max_features': 'log2', 'model__subsample': 0.8968112105768383, 'model__max_depth': 5, 'model__min_samples_leaf': 1, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:36:29,951] Trial 15 finished with value: -0.06903444056022859 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 241, 'model__learning_rate': 0.15942717210408902, 'model__max_features': 'log2', 'model__subsample': 0.8053289760718096, 'model__max_depth': 3, 'model__min_samples_leaf': 1, 'model__min_samples_split': 3}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:36:30,341] Trial 19 finished with value: -0.07699224789420803 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 157, 'model__learning_rate': 0.18782690649359474, 'model__max_features': 'log2', 'model__subsample': 0.7425650448995234, 'model__max_depth': 5, 'model__min_samples_leaf': 2, 'model__min_samples_split': 3}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:36:34,668] Trial 22 finished with value: -0.07145508980821497 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 163, 'model__learning_rate': 0.2956261216351252, 'model__max_features': 'log2', 'model__subsample': 0.9137720087295833, 'model__max_depth': 4, 'model__min_samples_leaf': 1, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:36:35,242] Trial 18 finished with value: -0.06621946615687521 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 249, 'model__learning_rate': 0.13670244884397298, 'model__max_features': 'sqrt', 'model__subsample': 0.9040502815238333, 'model__max_depth': 3, 'model__min_samples_leaf': 1, 'model__min_samples_split': 2}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:36:39,633] Trial 26 finished with value: -0.08702704342598268 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 169, 'model__learning_rate': 0.16833897677747878, 'model__max_features': 'log2', 'model__subsample': 0.9356921713610259, 'model__max_depth': 4, 'model__min_samples_leaf': 3, 'model__min_samples_split': 4}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:36:40,569] Trial 20 finished with value: -0.09302906518850976 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 282, 'model__learning_rate': 0.16212536372931569, 'model__max_features': 'log2', 'model__subsample': 0.7570030729963099, 'model__max_depth': 3, 'model__min_samples_leaf': 4, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:36:41,461] Trial 27 finished with value: -0.08765260905587138 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 166, 'model__learning_rate': 0.17292014993303545, 'model__max_features': 'log2', 'model__subsample': 0.9388245810809102, 'model__max_depth': 4, 'model__min_samples_leaf': 3, 'model__min_samples_split': 4}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:36:41,696] Trial 21 finished with value: -0.09976739547992687 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 257, 'model__learning_rate': 0.29905086832376654, 'model__max_features': 'log2', 'model__subsample': 0.9055343763868111, 'model__max_depth': 5, 'model__min_samples_leaf': 3, 'model__min_samples_split': 4}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:36:42,790] Trial 23 finished with value: -0.06955919864712046 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 264, 'model__learning_rate': 0.294214429045609, 'model__max_features': 'log2', 'model__subsample': 0.9248264295623714, 'model__max_depth': 4, 'model__min_samples_leaf': 1, 'model__min_samples_split': 4}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:36:43,468] Trial 28 finished with value: -0.08361438777796731 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 175, 'model__learning_rate': 0.1698170116833382, 'model__max_features': 'sqrt', 'model__subsample': 0.959027680708563, 'model__max_depth': 4, 'model__min_samples_leaf': 3, 'model__min_samples_split': 4}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:36:44,813] Trial 29 finished with value: -0.08996423199268466 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 159, 'model__learning_rate': 0.2780938838587441, 'model__max_features': 'sqrt', 'model__subsample': 0.9514533813315377, 'model__max_depth': 4, 'model__min_samples_leaf': 3, 'model__min_samples_split': 4}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:36:46,618] Trial 30 finished with value: -0.09573612538924588 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 177, 'model__learning_rate': 0.29605134518192827, 'model__max_features': 'sqrt', 'model__subsample': 0.9515752273970309, 'model__max_depth': 4, 'model__min_samples_leaf': 3, 'model__min_samples_split': 4}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:36:47,594] Trial 24 finished with value: -0.09358859408827981 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 288, 'model__learning_rate': 0.19406001220498245, 'model__max_features': 'log2', 'model__subsample': 0.9341331271484729, 'model__max_depth': 4, 'model__min_samples_leaf': 3, 'model__min_samples_split': 4}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:36:48,441] Trial 25 finished with value: -0.08981085830426876 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 281, 'model__learning_rate': 0.1844411868565164, 'model__max_features': 'sqrt', 'model__subsample': 0.9390114622079908, 'model__max_depth': 4, 'model__min_samples_leaf': 3, 'model__min_samples_split': 4}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:36:51,390] Trial 32 finished with value: -0.08707392348004975 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 181, 'model__learning_rate': 0.22007971916700908, 'model__max_features': 'log2', 'model__subsample': 0.950732384842852, 'model__max_depth': 4, 'model__min_samples_leaf': 3, 'model__min_samples_split': 4}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:36:51,495] Trial 31 finished with value: -0.09304616742457618 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 185, 'model__learning_rate': 0.26835250230629837, 'model__max_features': 'sqrt', 'model__subsample': 0.9602606931266096, 'model__max_depth': 4, 'model__min_samples_leaf': 3, 'model__min_samples_split': 4}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:36:56,318] Trial 33 finished with value: -0.09108973222415934 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 189, 'model__learning_rate': 0.2143521097318619, 'model__max_features': 'log2', 'model__subsample': 0.955543564267378, 'model__max_depth': 4, 'model__min_samples_leaf': 3, 'model__min_samples_split': 4}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:36:57,551] Trial 34 finished with value: -0.08409993080715904 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 192, 'model__learning_rate': 0.21441330348784746, 'model__max_features': 'sqrt', 'model__subsample': 0.9597723140607733, 'model__max_depth': 4, 'model__min_samples_leaf': 3, 'model__min_samples_split': 4}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:36:57,992] Trial 35 finished with value: -0.07427347046108601 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 186, 'model__learning_rate': 0.2096016750143252, 'model__max_features': 'sqrt', 'model__subsample': 0.967203446188239, 'model__max_depth': 4, 'model__min_samples_leaf': 2, 'model__min_samples_split': 4}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:36:58,291] Trial 36 finished with value: -0.0782753570704592 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 187, 'model__learning_rate': 0.2131272154230942, 'model__max_features': 'sqrt', 'model__subsample': 0.9600813376076467, 'model__max_depth': 4, 'model__min_samples_leaf': 2, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:36:59,989] Trial 37 finished with value: -0.07542323821043723 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 189, 'model__learning_rate': 0.21531653835476997, 'model__max_features': 'sqrt', 'model__subsample': 0.9647888345505394, 'model__max_depth': 6, 'model__min_samples_leaf': 2, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:37:00,790] Trial 38 finished with value: -0.07499586611555095 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 193, 'model__learning_rate': 0.21763318502400372, 'model__max_features': 'sqrt', 'model__subsample': 0.9697594293612621, 'model__max_depth': 6, 'model__min_samples_leaf': 2, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:37:01,831] Trial 39 finished with value: -0.07293545540570875 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 187, 'model__learning_rate': 0.22182328474059837, 'model__max_features': 'sqrt', 'model__subsample': 0.8826187669875261, 'model__max_depth': 6, 'model__min_samples_leaf': 2, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:37:03,961] Trial 41 finished with value: -0.07198047107731743 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 186, 'model__learning_rate': 0.21491871235053694, 'model__max_features': 'log2', 'model__subsample': 0.9758350870926803, 'model__max_depth': 6, 'model__min_samples_leaf': 2, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:37:05,437] Trial 42 finished with value: -0.07743444402634912 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 198, 'model__learning_rate': 0.2209088390767625, 'model__max_features': 'log2', 'model__subsample': 0.9780332311564078, 'model__max_depth': 6, 'model__min_samples_leaf': 2, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:37:05,685] Trial 40 finished with value: -0.07312009588887071 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 222, 'model__learning_rate': 0.2176159798772496, 'model__max_features': 'log2', 'model__subsample': 0.9738939961980106, 'model__max_depth': 6, 'model__min_samples_leaf': 2, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:37:08,300] Trial 43 finished with value: -0.07773683613664503 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 198, 'model__learning_rate': 0.2140669179738412, 'model__max_features': 'log2', 'model__subsample': 0.7881479594279345, 'model__max_depth': 6, 'model__min_samples_leaf': 2, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:37:09,977] Trial 44 finished with value: -0.07653001675413662 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 210, 'model__learning_rate': 0.21546551275526285, 'model__max_features': 'log2', 'model__subsample': 0.9787890433006827, 'model__max_depth': 6, 'model__min_samples_leaf': 2, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:37:13,646] Trial 45 finished with value: -0.07555942396666161 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 202, 'model__learning_rate': 0.24100687211412336, 'model__max_features': 'log2', 'model__subsample': 0.7998564249913022, 'model__max_depth': 6, 'model__min_samples_leaf': 2, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:37:16,409] Trial 46 finished with value: -0.0753046907506927 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 215, 'model__learning_rate': 0.1063938691541672, 'model__max_features': 'log2', 'model__subsample': 0.9818692877483581, 'model__max_depth': 6, 'model__min_samples_leaf': 2, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:37:16,652] Trial 48 finished with value: -0.07809054872518473 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 221, 'model__learning_rate': 0.10117276975898236, 'model__max_features': 'log2', 'model__subsample': 0.7802686467882826, 'model__max_depth': 6, 'model__min_samples_leaf': 2, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:37:17,886] Trial 47 finished with value: -0.07518962097132528 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 225, 'model__learning_rate': 0.10262108159831036, 'model__max_features': 'log2', 'model__subsample': 0.8800097677359092, 'model__max_depth': 6, 'model__min_samples_leaf': 2, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:37:18,294] Trial 54 finished with value: -0.07360637959104785 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 141, 'model__learning_rate': 0.12082000266591665, 'model__max_features': 'sqrt', 'model__subsample': 0.7900507546905482, 'model__max_depth': 3, 'model__min_samples_leaf': 1, 'model__min_samples_split': 2}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:37:19,596] Trial 49 finished with value: -0.07150989396524683 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 221, 'model__learning_rate': 0.2414362511545269, 'model__max_features': 'log2', 'model__subsample': 0.9815421433961629, 'model__max_depth': 6, 'model__min_samples_leaf': 1, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:37:20,368] Trial 50 finished with value: -0.06303034206503613 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 224, 'model__learning_rate': 0.09370522954989008, 'model__max_features': 'log2', 'model__subsample': 0.8815745577411572, 'model__max_depth': 5, 'model__min_samples_leaf': 1, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:37:20,997] Trial 51 finished with value: -0.06594705391645937 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 225, 'model__learning_rate': 0.08842337032746472, 'model__max_features': 'log2', 'model__subsample': 0.7951824079914628, 'model__max_depth': 5, 'model__min_samples_leaf': 1, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:37:22,449] Trial 52 finished with value: -0.07094028014041359 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 223, 'model__learning_rate': 0.09204180346121779, 'model__max_features': 'log2', 'model__subsample': 0.793465646522126, 'model__max_depth': 3, 'model__min_samples_leaf': 1, 'model__min_samples_split': 2}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:37:23,152] Trial 56 finished with value: -0.07442226081707258 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 141, 'model__learning_rate': 0.09922943412316336, 'model__max_features': 'sqrt', 'model__subsample': 0.8474078371367976, 'model__max_depth': 3, 'model__min_samples_leaf': 1, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:37:23,443] Trial 53 finished with value: -0.07161423969285494 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 213, 'model__learning_rate': 0.09120548329379942, 'model__max_features': 'log2', 'model__subsample': 0.7954967147411213, 'model__max_depth': 3, 'model__min_samples_leaf': 1, 'model__min_samples_split': 2}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:37:26,883] Trial 57 finished with value: -0.07602159604408176 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 142, 'model__learning_rate': 0.1417703383600982, 'model__max_features': 'sqrt', 'model__subsample': 0.849700190926119, 'model__max_depth': 3, 'model__min_samples_leaf': 1, 'model__min_samples_split': 2}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:37:27,289] Trial 55 finished with value: -0.07003913293019896 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 219, 'model__learning_rate': 0.10521184652350475, 'model__max_features': 'sqrt', 'model__subsample': 0.8467077180092029, 'model__max_depth': 3, 'model__min_samples_leaf': 1, 'model__min_samples_split': 2}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:37:29,610] Trial 58 finished with value: -0.07503375280606131 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 142, 'model__learning_rate': 0.13853115646420527, 'model__max_features': 'sqrt', 'model__subsample': 0.8473381801943636, 'model__max_depth': 3, 'model__min_samples_leaf': 1, 'model__min_samples_split': 2}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:37:29,975] Trial 59 finished with value: -0.07079530092309269 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 141, 'model__learning_rate': 0.13519759089937905, 'model__max_features': 'sqrt', 'model__subsample': 0.8871718806600792, 'model__max_depth': 3, 'model__min_samples_leaf': 1, 'model__min_samples_split': 2}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:37:30,722] Trial 60 finished with value: -0.07584828517218468 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 138, 'model__learning_rate': 0.13773033620262823, 'model__max_features': 'sqrt', 'model__subsample': 0.8473866581771229, 'model__max_depth': 3, 'model__min_samples_leaf': 1, 'model__min_samples_split': 2}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:37:32,229] Trial 63 finished with value: -0.06774096285385951 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 124, 'model__learning_rate': 0.14003090348625247, 'model__max_features': 'sqrt', 'model__subsample': 0.8550052533863398, 'model__max_depth': 5, 'model__min_samples_leaf': 1, 'model__min_samples_split': 2}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:37:32,468] Trial 64 finished with value: -0.07716390843349435 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 120, 'model__learning_rate': 0.08634199575601727, 'model__max_features': 'log2', 'model__subsample': 0.842743986795919, 'model__max_depth': 5, 'model__min_samples_leaf': 1, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:37:39,195] Trial 61 finished with value: -0.06955248267215357 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 241, 'model__learning_rate': 0.15260003415317014, 'model__max_features': 'sqrt', 'model__subsample': 0.8493296820591585, 'model__max_depth': 3, 'model__min_samples_leaf': 1, 'model__min_samples_split': 2}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:37:40,260] Trial 62 finished with value: -0.06656756207927048 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 244, 'model__learning_rate': 0.15037542249134755, 'model__max_features': 'log2', 'model__subsample': 0.8427280546198302, 'model__max_depth': 3, 'model__min_samples_leaf': 1, 'model__min_samples_split': 2}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:37:43,339] Trial 66 finished with value: -0.06729923399136568 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 235, 'model__learning_rate': 0.08491972809033217, 'model__max_features': 'log2', 'model__subsample': 0.8405624765941342, 'model__max_depth': 5, 'model__min_samples_leaf': 1, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:37:43,455] Trial 65 finished with value: -0.06725629334774572 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 243, 'model__learning_rate': 0.07399306334166812, 'model__max_features': 'log2', 'model__subsample': 0.855941483246343, 'model__max_depth': 5, 'model__min_samples_leaf': 1, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:37:43,781] Trial 67 finished with value: -0.06756278840289467 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 240, 'model__learning_rate': 0.07671874268493792, 'model__max_features': 'log2', 'model__subsample': 0.820999572523482, 'model__max_depth': 5, 'model__min_samples_leaf': 1, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:37:47,123] Trial 68 finished with value: -0.06589700649305671 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 241, 'model__learning_rate': 0.07263943855462274, 'model__max_features': 'log2', 'model__subsample': 0.8128368388877462, 'model__max_depth': 5, 'model__min_samples_leaf': 1, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:37:47,684] Trial 69 finished with value: -0.06736756707503451 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 240, 'model__learning_rate': 0.07428508575889825, 'model__max_features': 'log2', 'model__subsample': 0.8169373272678497, 'model__max_depth': 5, 'model__min_samples_leaf': 1, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:37:50,216] Trial 71 finished with value: -0.06733785620220777 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 242, 'model__learning_rate': 0.07056924231846523, 'model__max_features': 'log2', 'model__subsample': 0.8175071761361993, 'model__max_depth': 5, 'model__min_samples_leaf': 1, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:37:50,957] Trial 72 finished with value: -0.06684011426728244 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 240, 'model__learning_rate': 0.06937748274721868, 'model__max_features': 'log2', 'model__subsample': 0.8196804219198988, 'model__max_depth': 5, 'model__min_samples_leaf': 1, 'model__min_samples_split': 3}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:37:51,856] Trial 70 finished with value: -0.06605523357550333 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 265, 'model__learning_rate': 0.07007848874354677, 'model__max_features': 'log2', 'model__subsample': 0.8195183372521533, 'model__max_depth': 5, 'model__min_samples_leaf': 1, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:37:52,798] Trial 74 finished with value: -0.0671412390374653 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 240, 'model__learning_rate': 0.07391032250962266, 'model__max_features': 'log2', 'model__subsample': 0.816239177424765, 'model__max_depth': 5, 'model__min_samples_leaf': 1, 'model__min_samples_split': 3}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:37:53,154] Trial 73 finished with value: -0.06767956638399233 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 239, 'model__learning_rate': 0.07930989090864113, 'model__max_features': 'log2', 'model__subsample': 0.8976803917766136, 'model__max_depth': 5, 'model__min_samples_leaf': 1, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:37:56,866] Trial 81 finished with value: -0.14296460952673712 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 95, 'model__learning_rate': 0.05054344415802284, 'model__max_features': 'log2', 'model__subsample': 0.7690529121505243, 'model__max_depth': 5, 'model__min_samples_leaf': 5, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:37:59,448] Trial 75 finished with value: -0.06663563124123528 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 242, 'model__learning_rate': 0.07286114920136902, 'model__max_features': 'log2', 'model__subsample': 0.818009729937405, 'model__max_depth': 5, 'model__min_samples_leaf': 1, 'model__min_samples_split': 3}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:38:02,094] Trial 76 finished with value: -0.06716307345574833 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 262, 'model__learning_rate': 0.07539709492215363, 'model__max_features': 'log2', 'model__subsample': 0.8158729793857152, 'model__max_depth': 5, 'model__min_samples_leaf': 1, 'model__min_samples_split': 3}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:38:04,737] Trial 77 finished with value: -0.06688279839830177 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 259, 'model__learning_rate': 0.07114117453864208, 'model__max_features': 'log2', 'model__subsample': 0.8114666340194179, 'model__max_depth': 5, 'model__min_samples_leaf': 1, 'model__min_samples_split': 3}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:38:05,728] Trial 79 finished with value: -0.07171475011913743 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 256, 'model__learning_rate': 0.053462874808271554, 'model__max_features': 'log2', 'model__subsample': 0.8999934576360007, 'model__max_depth': 5, 'model__min_samples_leaf': 1, 'model__min_samples_split': 3}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:38:06,277] Trial 78 finished with value: -0.08438481398802375 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 262, 'model__learning_rate': 0.12563455836377785, 'model__max_features': 'log2', 'model__subsample': 0.9018855570227613, 'model__max_depth': 5, 'model__min_samples_leaf': 5, 'model__min_samples_split': 3}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:38:08,850] Trial 80 finished with value: -0.06889030559852957 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 267, 'model__learning_rate': 0.0507461804100251, 'model__max_features': 'log2', 'model__subsample': 0.7783456864264717, 'model__max_depth': 5, 'model__min_samples_leaf': 1, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:38:12,662] Trial 83 finished with value: -0.06543287715431799 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 265, 'model__learning_rate': 0.05359411354386087, 'model__max_features': 'log2', 'model__subsample': 0.7695598219493597, 'model__max_depth': 5, 'model__min_samples_leaf': 1, 'model__min_samples_split': 3}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:38:13,652] Trial 82 finished with value: -0.07023816708604431 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 269, 'model__learning_rate': 0.23050066186243698, 'model__max_features': 'log2', 'model__subsample': 0.9070031251577276, 'model__max_depth': 5, 'model__min_samples_leaf': 1, 'model__min_samples_split': 3}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:38:14,224] Trial 85 finished with value: -0.06595156311077674 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 264, 'model__learning_rate': 0.05817612066678745, 'model__max_features': 'log2', 'model__subsample': 0.7683318856841037, 'model__max_depth': 5, 'model__min_samples_leaf': 1, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:38:14,883] Trial 86 finished with value: -0.09143919296979605 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 269, 'model__learning_rate': 0.05301846558108017, 'model__max_features': 'log2', 'model__subsample': 0.7685113142286156, 'model__max_depth': 5, 'model__min_samples_leaf': 5, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:38:16,012] Trial 84 finished with value: -0.08666159742384488 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 299, 'model__learning_rate': 0.25450688973023705, 'model__max_features': 'log2', 'model__subsample': 0.7722359807647747, 'model__max_depth': 5, 'model__min_samples_leaf': 5, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:38:19,253] Trial 87 finished with value: -0.06805897750152858 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 261, 'model__learning_rate': 0.06138573030275701, 'model__max_features': 'log2', 'model__subsample': 0.8660338862033341, 'model__max_depth': 5, 'model__min_samples_leaf': 1, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:38:19,701] Trial 91 finished with value: -0.0727111428185903 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 152, 'model__learning_rate': 0.26545819689691547, 'model__max_features': 'log2', 'model__subsample': 0.8675016880248242, 'model__max_depth': 5, 'model__min_samples_leaf': 1, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:38:21,699] Trial 88 finished with value: -0.07093187054227494 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 271, 'model__learning_rate': 0.25261919516189885, 'model__max_features': 'log2', 'model__subsample': 0.8050386835822347, 'model__max_depth': 5, 'model__min_samples_leaf': 1, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:38:23,336] Trial 89 finished with value: -0.09129826865336998 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 253, 'model__learning_rate': 0.06026770297760562, 'model__max_features': 'log2', 'model__subsample': 0.8651154310761741, 'model__max_depth': 5, 'model__min_samples_leaf': 4, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:38:23,700] Trial 90 finished with value: -0.0908253964487985 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 230, 'model__learning_rate': 0.20316353966232306, 'model__max_features': 'log2', 'model__subsample': 0.8304805160558923, 'model__max_depth': 5, 'model__min_samples_leaf': 4, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:38:27,594] Trial 92 finished with value: -0.07825060225140944 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 273, 'model__learning_rate': 0.28229999874961, 'model__max_features': 'log2', 'model__subsample': 0.9131840822132534, 'model__max_depth': 5, 'model__min_samples_leaf': 1, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:38:27,916] Trial 98 finished with value: -0.09655706276946292 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 172, 'model__learning_rate': 0.0603267558204354, 'model__max_features': 'log2', 'model__subsample': 0.7339525480879687, 'model__max_depth': 5, 'model__min_samples_leaf': 4, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:38:28,786] Trial 93 finished with value: -0.0893900827835786 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 271, 'model__learning_rate': 0.26825477836113865, 'model__max_features': 'log2', 'model__subsample': 0.9109914450759751, 'model__max_depth': 5, 'model__min_samples_leaf': 4, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:38:30,389] Trial 94 finished with value: -0.08646512506336217 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 297, 'model__learning_rate': 0.230178734129584, 'model__max_features': 'log2', 'model__subsample': 0.7445945578699037, 'model__max_depth': 5, 'model__min_samples_leaf': 4, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:38:30,736] Trial 95 finished with value: -0.06360773502256041 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 297, 'model__learning_rate': 0.05969470302468417, 'model__max_features': 'log2', 'model__subsample': 0.754784443239886, 'model__max_depth': 5, 'model__min_samples_leaf': 1, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:38:30,796] Trial 99 finished with value: -0.0977735785829499 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 229, 'model__learning_rate': 0.06203105033896274, 'model__max_features': 'log2', 'model__subsample': 0.7358080472758896, 'model__max_depth': 4, 'model__min_samples_leaf': 4, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:38:30,814] Trial 96 finished with value: -0.08690000038891135 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 297, 'model__learning_rate': 0.062325830987642536, 'model__max_features': 'log2', 'model__subsample': 0.7514501104063488, 'model__max_depth': 5, 'model__min_samples_leaf': 4, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# [I 2025-09-26 17:38:30,914] Trial 97 finished with value: -0.06530926743675138 and parameters: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 298, 'model__learning_rate': 0.061792561093240626, 'model__max_features': 'log2', 'model__subsample': 0.7464545273051545, 'model__max_depth': 5, 'model__min_samples_leaf': 1, 'model__min_samples_split': 5}. Best is trial 7 with value: -0.06200511376757413.
# Best neg score: -0.06200511376757413
# Best Params: {'regressor': 'GradientBoostingRegressor', 'model__n_estimators': 134, 'model__learning_rate': 0.2700045559489739, 'model__max_features': 'sqrt', 'model__subsample': 0.9961388057454358, 'model__max_depth': 4, 'model__min_samples_leaf': 1, 'model__min_samples_split': 5}
# MSE: 0.06276607269743066
# MAE: 0.14593791828398273
# R2: 0.8718923585338596
