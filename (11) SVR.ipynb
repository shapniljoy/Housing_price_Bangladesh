# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import warnings
warnings.filterwarnings('ignore')
import optuna
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import category_encoders as ce
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder,StandardScaler,OrdinalEncoder,TargetEncoder,PowerTransformer
from sklearn.compose import ColumnTransformer,TransformedTargetRegressor
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split,GridSearchCV,cross_val_score,KFold,RandomizedSearchCV
from lightgbm import LGBMRegressor
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.neural_network import MLPRegressor
from xgboost import XGBRegressor
import xgboost as xgb
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
import optuna
from plotly.io import show
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
df = pd.read_csv('final_data.csv')
df = df.drop(['Title','Price_per_sqft','Is_in_Dhaka'],axis=1)
df.head()
# Out:
#    Bedrooms  Bathrooms  Floor_area   City location_area  Price_in_Cr  \
# 0       3.0        4.0      1960.0  dhaka       gulshan         3.90
# 1       3.0        3.0      1705.0  dhaka     kalabagan         1.69
# 2       3.0        3.0      1370.0  dhaka     dhanmondi         1.25
# 3       3.0        3.0      2125.0  dhaka   bashundhara         2.00
# 4       3.0        3.0      2687.0  dhaka        banani         4.75
#
#   floor_level
# 0         low
# 1         low
# 2      medium
# 3      medium
# 4      medium

# %%
x = df.drop('Price_in_Cr',axis=1)
y = df['Price_in_Cr']

# %% [markdown]
# # Optuna

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

floor_area_pipe = Pipeline([
    ('log_transform',PowerTransformer(method='yeo-johnson')),
    ('scalar',StandardScaler())
])

transformer = ColumnTransformer([
    ("floor_area",floor_area_pipe,['Floor_area']),
    ("log_transform",PowerTransformer(method='yeo-johnson'),['Floor_area']),
    ('Onehot',OneHotEncoder(handle_unknown='ignore',sparse_output=False),['City','Bedrooms','Bathrooms','location_area']),
    ('Ordinal',OrdinalEncoder(handle_unknown='use_encoded_value',unknown_value=-1),['floor_level']),
],remainder='passthrough')


def objective(trial,preprocessor):
     regressor_name = trial.suggest_categorical('regressor',['SVR'])

     if regressor_name == 'SVR':
        kernel = trial.suggest_categorical('model__kernel',['rbf','linear','poly','sigmoid'])
        C = trial.suggest_float('model__C',0.01,1000)
        epsilon = trial.suggest_float('model__epsilon', 0.01,1)
        gamma = trial.suggest_categorical('model__gamma', ['scale', 'auto'])

     

        model_pipe = Pipeline([
            ('preprocessing',transformer),
            ('model',SVR(kernel=kernel,C=C,epsilon=epsilon,gamma=gamma))
        ])

                              
        final_pipe = TransformedTargetRegressor(regressor=model_pipe,func=np.log1p,inverse_func=np.expm1)

        trial.set_user_attr('model',final_pipe)

        cv = cross_val_score(final_pipe,x_train,y_train,cv=KFold(n_splits=5,shuffle=True,random_state=0),scoring='neg_mean_squared_error')

        return cv.mean()
     

study = optuna.create_study(direction='maximize',sampler=optuna.samplers.TPESampler(seed=0),pruner=optuna.pruners.HyperbandPruner())
study.optimize(lambda trial: objective(trial,transformer),n_trials=100,n_jobs=-1)

print(f'Best neg score: {study.best_value}')
print(f'Best Params: {study.best_params}')

final_model = study.best_trial.user_attrs['model']
final_model.fit(x_train,y_train)
y_pred = final_model.predict(x_test)

print(f'MSE: {mean_squared_error(y_test,y_pred)}')
print(f'MAE: {mean_absolute_error(y_test,y_pred)}')
print(f'R2: {r2_score(y_test,y_pred)}')
# Out:
# [I 2025-09-26 17:53:21,671] A new study created in memory with name: no-name-2ba81a85-79f3-459b-89f2-82c3901ba3af
# [I 2025-09-26 17:53:22,869] Trial 2 finished with value: -1.671132546303032 and parameters: {'regressor': 'SVR', 'model__kernel': 'poly', 'model__C': 796.1808977908337, 'model__epsilon': 0.9100188794220854, 'model__gamma': 'scale'}. Best is trial 2 with value: -1.671132546303032.
# [I 2025-09-26 17:53:22,886] Trial 1 finished with value: -1.4635890311344195 and parameters: {'regressor': 'SVR', 'model__kernel': 'rbf', 'model__C': 85.92401452450841, 'model__epsilon': 0.8324366754129553, 'model__gamma': 'auto'}. Best is trial 1 with value: -1.4635890311344195.
# [I 2025-09-26 17:53:22,925] Trial 8 finished with value: -0.24001814978827557 and parameters: {'regressor': 'SVR', 'model__kernel': 'linear', 'model__C': 419.7128157651462, 'model__epsilon': 0.44688745042413325, 'model__gamma': 'auto'}. Best is trial 8 with value: -0.24001814978827557.
# [I 2025-09-26 17:53:22,994] Trial 6 finished with value: -1.7271484201209493 and parameters: {'regressor': 'SVR', 'model__kernel': 'poly', 'model__C': 35.6092742057932, 'model__epsilon': 0.9198443411407804, 'model__gamma': 'scale'}. Best is trial 8 with value: -0.24001814978827557.
# [I 2025-09-26 17:53:23,000] Trial 4 finished with value: -1.700123665042542 and parameters: {'regressor': 'SVR', 'model__kernel': 'sigmoid', 'model__C': 449.8297392304733, 'model__epsilon': 0.8766002779604529, 'model__gamma': 'auto'}. Best is trial 8 with value: -0.24001814978827557.
# [I 2025-09-26 17:53:23,006] Trial 5 finished with value: -0.48098913591754666 and parameters: {'regressor': 'SVR', 'model__kernel': 'rbf', 'model__C': 606.4449677689014, 'model__epsilon': 0.6267116766586557, 'model__gamma': 'auto'}. Best is trial 8 with value: -0.24001814978827557.
# [I 2025-09-26 17:53:23,008] Trial 11 finished with value: -0.3282745078786287 and parameters: {'regressor': 'SVR', 'model__kernel': 'rbf', 'model__C': 685.957218033541, 'model__epsilon': 0.4676392957508048, 'model__gamma': 'scale'}. Best is trial 8 with value: -0.24001814978827557.
# [I 2025-09-26 17:53:23,020] Trial 9 finished with value: -1.2868518817319736 and parameters: {'regressor': 'SVR', 'model__kernel': 'poly', 'model__C': 805.8547035905166, 'model__epsilon': 0.8253730998454234, 'model__gamma': 'auto'}. Best is trial 8 with value: -0.24001814978827557.
# [W 2025-09-26 17:53:23,616] Trial 7 failed with parameters: {'regressor': 'SVR', 'model__kernel': 'sigmoid', 'model__C': 751.3670118737463, 'model__epsilon': 0.3108723425038544, 'model__gamma': 'scale'} because of the following error: The value nan is not acceptable.
# [W 2025-09-26 17:53:23,625] Trial 7 failed with value np.float64(nan).
# [I 2025-09-26 17:53:23,956] Trial 13 finished with value: -1.6932533017279288 and parameters: {'regressor': 'SVR', 'model__kernel': 'rbf', 'model__C': 608.8755815576753, 'model__epsilon': 0.8751649106973811, 'model__gamma': 'auto'}. Best is trial 8 with value: -0.24001814978827557.
# [I 2025-09-26 17:53:24,038] Trial 19 finished with value: -1.9861775087468119 and parameters: {'regressor': 'SVR', 'model__kernel': 'linear', 'model__C': 14.350982241155888, 'model__epsilon': 0.9418815642713287, 'model__gamma': 'auto'}. Best is trial 8 with value: -0.24001814978827557.
# [I 2025-09-26 17:53:24,077] Trial 17 finished with value: -0.3804811776962326 and parameters: {'regressor': 'SVR', 'model__kernel': 'linear', 'model__C': 752.4694850588274, 'model__epsilon': 0.5529610084076055, 'model__gamma': 'scale'}. Best is trial 8 with value: -0.24001814978827557.
# [I 2025-09-26 17:53:24,086] Trial 15 finished with value: -0.3614058986329417 and parameters: {'regressor': 'SVR', 'model__kernel': 'linear', 'model__C': 340.9192449249115, 'model__epsilon': 0.5395061037490844, 'model__gamma': 'auto'}. Best is trial 8 with value: -0.24001814978827557.
# [I 2025-09-26 17:53:24,534] Trial 20 finished with value: -0.13348654620021455 and parameters: {'regressor': 'SVR', 'model__kernel': 'poly', 'model__C': 231.07905331082657, 'model__epsilon': 0.14289612546934718, 'model__gamma': 'auto'}. Best is trial 20 with value: -0.13348654620021455.
# [W 2025-09-26 17:53:24,755] Trial 18 failed with parameters: {'regressor': 'SVR', 'model__kernel': 'sigmoid', 'model__C': 954.7038778269064, 'model__epsilon': 0.17517218497507883, 'model__gamma': 'scale'} because of the following error: The value nan is not acceptable.
# [W 2025-09-26 17:53:24,756] Trial 18 failed with value np.float64(nan).
# [W 2025-09-26 17:53:24,764] Trial 16 failed with parameters: {'regressor': 'SVR', 'model__kernel': 'sigmoid', 'model__C': 198.91394975371568, 'model__epsilon': 0.09230716053991243, 'model__gamma': 'scale'} because of the following error: The value nan is not acceptable.
# [W 2025-09-26 17:53:24,770] Trial 16 failed with value np.float64(nan).
# [I 2025-09-26 17:53:24,936] Trial 12 finished with value: -1.7273245236535522e+44 and parameters: {'regressor': 'SVR', 'model__kernel': 'sigmoid', 'model__C': 728.1238233810245, 'model__epsilon': 0.2526783864449947, 'model__gamma': 'auto'}. Best is trial 20 with value: -0.13348654620021455.
# [W 2025-09-26 17:53:25,516] Trial 23 failed with parameters: {'regressor': 'SVR', 'model__kernel': 'sigmoid', 'model__C': 952.6743671690817, 'model__epsilon': 0.2348736084657293, 'model__gamma': 'scale'} because of the following error: The value nan is not acceptable.
# [W 2025-09-26 17:53:25,519] Trial 23 failed with value np.float64(nan).
# [W 2025-09-26 17:53:25,553] Trial 24 failed with parameters: {'regressor': 'SVR', 'model__kernel': 'sigmoid', 'model__C': 244.77834942985376, 'model__epsilon': 0.22718144944586072, 'model__gamma': 'scale'} because of the following error: The value nan is not acceptable.
# [W 2025-09-26 17:53:25,555] Trial 24 failed with value np.float64(nan).
# [I 2025-09-26 17:53:26,292] Trial 25 finished with value: -597314549366045.6 and parameters: {'regressor': 'SVR', 'model__kernel': 'sigmoid', 'model__C': 266.5866794081148, 'model__epsilon': 0.12396590777549556, 'model__gamma': 'auto'}. Best is trial 20 with value: -0.13348654620021455.
# [I 2025-09-26 17:53:26,875] Trial 27 finished with value: -77886901601251.22 and parameters: {'regressor': 'SVR', 'model__kernel': 'sigmoid', 'model__C': 252.20951067562726, 'model__epsilon': 0.09262732821184783, 'model__gamma': 'auto'}. Best is trial 20 with value: -0.13348654620021455.
# [I 2025-09-26 17:53:26,906] Trial 26 finished with value: -1879318545545996.0 and parameters: {'regressor': 'SVR', 'model__kernel': 'sigmoid', 'model__C': 273.97713586708454, 'model__epsilon': 0.1023079705668512, 'model__gamma': 'auto'}. Best is trial 20 with value: -0.13348654620021455.
# [I 2025-09-26 17:53:27,221] Trial 32 finished with value: -0.21558886284857662 and parameters: {'regressor': 'SVR', 'model__kernel': 'poly', 'model__C': 438.194948110645, 'model__epsilon': 0.30022480994147355, 'model__gamma': 'auto'}. Best is trial 20 with value: -0.13348654620021455.
# [I 2025-09-26 17:53:27,249] Trial 31 finished with value: -0.14205969261812765 and parameters: {'regressor': 'SVR', 'model__kernel': 'linear', 'model__C': 187.70522338817995, 'model__epsilon': 0.3311853559306337, 'model__gamma': 'auto'}. Best is trial 20 with value: -0.13348654620021455.
# [I 2025-09-26 17:53:27,563] Trial 34 finished with value: -0.33499951179075954 and parameters: {'regressor': 'SVR', 'model__kernel': 'poly', 'model__C': 948.8967787638969, 'model__epsilon': 0.3309660467736699, 'model__gamma': 'scale'}. Best is trial 20 with value: -0.13348654620021455.
# [I 2025-09-26 17:53:29,313] Trial 33 finished with value: -0.1286993799780341 and parameters: {'regressor': 'SVR', 'model__kernel': 'linear', 'model__C': 953.9708139918735, 'model__epsilon': 0.3127477517041142, 'model__gamma': 'auto'}. Best is trial 33 with value: -0.1286993799780341.
# [I 2025-09-26 17:53:29,987] Trial 10 finished with value: -0.09816031032299836 and parameters: {'regressor': 'SVR', 'model__kernel': 'linear', 'model__C': 644.7565268474629, 'model__epsilon': 0.2558272411319898, 'model__gamma': 'scale'}. Best is trial 10 with value: -0.09816031032299836.
# [I 2025-09-26 17:53:32,522] Trial 35 finished with value: -0.12611979909142015 and parameters: {'regressor': 'SVR', 'model__kernel': 'linear', 'model__C': 985.6174160767789, 'model__epsilon': 0.3090354246811698, 'model__gamma': 'scale'}. Best is trial 10 with value: -0.09816031032299836.
# [I 2025-09-26 17:53:33,558] Trial 0 finished with value: -0.0912884785306161 and parameters: {'regressor': 'SVR', 'model__kernel': 'linear', 'model__C': 661.2859162379235, 'model__epsilon': 0.24297378426415994, 'model__gamma': 'auto'}. Best is trial 0 with value: -0.0912884785306161.
# [I 2025-09-26 17:53:38,602] Trial 37 finished with value: -0.08117958055833874 and parameters: {'regressor': 'SVR', 'model__kernel': 'linear', 'model__C': 187.45640001707568, 'model__epsilon': 0.20519152987774397, 'model__gamma': 'auto'}. Best is trial 37 with value: -0.08117958055833874.
# [I 2025-09-26 17:53:50,048] Trial 36 finished with value: -0.07377023646080809 and parameters: {'regressor': 'SVR', 'model__kernel': 'linear', 'model__C': 166.02830870882354, 'model__epsilon': 0.17569654121343964, 'model__gamma': 'auto'}. Best is trial 36 with value: -0.07377023646080809.
# [I 2025-09-26 17:54:28,103] Trial 40 finished with value: -0.08261308466819224 and parameters: {'regressor': 'SVR', 'model__kernel': 'linear', 'model__C': 842.4315238847248, 'model__epsilon': 0.21075248046610476, 'model__gamma': 'scale'}. Best is trial 36 with value: -0.07377023646080809.
# [I 2025-09-26 17:54:33,533] Trial 22 finished with value: -0.06906738435931484 and parameters: {'regressor': 'SVR', 'model__kernel': 'linear', 'model__C': 296.85623819665705, 'model__epsilon': 0.12376323549509044, 'model__gamma': 'scale'}. Best is trial 22 with value: -0.06906738435931484.
# [I 2025-09-26 17:54:45,614] Trial 38 finished with value: -0.08060835901594457 and parameters: {'regressor': 'SVR', 'model__kernel': 'linear', 'model__C': 995.7843206743178, 'model__epsilon': 0.20119348474495796, 'model__gamma': 'scale'}. Best is trial 22 with value: -0.06906738435931484.
# [I 2025-09-26 17:54:51,851] Trial 39 finished with value: -0.07567340754083621 and parameters: {'regressor': 'SVR', 'model__kernel': 'linear', 'model__C': 977.8864211869151, 'model__epsilon': 0.1875961572005365, 'model__gamma': 'scale'}. Best is trial 22 with value: -0.06906738435931484.
# [I 2025-09-26 17:55:06,646] Trial 43 finished with value: -0.07550951864450037 and parameters: {'regressor': 'SVR', 'model__kernel': 'linear', 'model__C': 525.6953757744797, 'model__epsilon': 0.1872570131863897, 'model__gamma': 'scale'}. Best is trial 22 with value: -0.06906738435931484.
# [I 2025-09-26 17:56:32,062] Trial 45 finished with value: -0.07109694981491829 and parameters: {'regressor': 'SVR', 'model__kernel': 'linear', 'model__C': 110.93602379268474, 'model__epsilon': 0.04156993707159129, 'model__gamma': 'scale'}. Best is trial 22 with value: -0.06906738435931484.
# [I 2025-09-26 17:56:37,947] Trial 42 finished with value: -0.07083660891973982 and parameters: {'regressor': 'SVR', 'model__kernel': 'linear', 'model__C': 155.2442586104721, 'model__epsilon': 0.03694612569350103, 'model__gamma': 'auto'}. Best is trial 22 with value: -0.06906738435931484.
# [I 2025-09-26 17:56:55,637] Trial 44 finished with value: -0.07061494228426844 and parameters: {'regressor': 'SVR', 'model__kernel': 'linear', 'model__C': 116.12853188699982, 'model__epsilon': 0.02761957927888592, 'model__gamma': 'scale'}. Best is trial 22 with value: -0.06906738435931484.
# [I 2025-09-26 17:58:28,456] Trial 29 finished with value: -0.07054486270629781 and parameters: {'regressor': 'SVR', 'model__kernel': 'linear', 'model__C': 255.11593339340808, 'model__epsilon': 0.032213007127533, 'model__gamma': 'auto'}. Best is trial 22 with value: -0.06906738435931484.

# %%
final_model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 final_model
#
# NameError: name 'final_model' is not defined
